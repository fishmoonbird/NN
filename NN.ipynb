# %% [markdown]
# <a href="https://colab.research.google.com/github/fishmoonbird/NN/blob/main/NN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 1

# %%
b = 2

# %%
c = 3

# %%
d = 4
